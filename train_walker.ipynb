# %%
import os
os.environ["MUJOCO_GL"] = "egl"

import mujoco
import gymnasium as gym
import numpy as np
import mediapy as media
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

from stable_baselines3 import SAC # if this doesnt work, uninstall reinstall torch
from stable_baselines3.common.env_util import make_vec_env

from walker2d_env import Walker2dEnv

np.set_printoptions(precision=3, suppress=True, linewidth=100)

# %%
gym.register(
    id="gymnasium_env/Walker2d-v0",
    entry_point=Walker2dEnv,
    kwargs={'xml_file': './assets/walker2d.xml'}
)

env = gym.make('gymnasium_env/Walker2d-v0', render_mode='human')
# env = make_vec_env('gymnasium_env/Walker2d-v0', n_envs=1)

# %%
model = SAC("MlpPolicy", env, verbose=1, tensorboard_log="./sac_logs/")
model.learn(total_timesteps=1_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./sac_logs/SAC_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 0.435    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 3490     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 81       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -0.847   |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 260      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 166      |
# | train/             |          |
# |    actor_loss      | -8.15    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.981    |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -1.52    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 214      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 258      |
# | train/             |          |
# |    actor_loss      | -9.28    |
# |    critic_loss     | 1.89     |
# |    ent_coef        | 0.954    |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 157      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | -0.228   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 197      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 360      |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.925    |
# |    ent_coef_loss   | -0.779   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | 3.29     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 186      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 512      |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.884    |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 411      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27       |
# |    ep_rew_mean     | 3.37     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 180      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 648      |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.849    |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 547      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.6     |
# |    ep_rew_mean     | 3.91     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 174      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 970      |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 1.77     |
# |    ent_coef        | 0.773    |
# |    ent_coef_loss   | -2.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 869      |
# ---------------------------------

# %%
obs, info = env.reset()
for _ in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    env.render()  # This works locally; may not work over SSH
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       5 action, _states = model.predict(obs, deterministic=True)
#       6 obs, reward, done, truncated, info = env.step(action)
# ----> 7 env.render()  # This works locally; may not work over SSH
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/wrappers/common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/wrappers/common.py:301, in PassiveEnvChecker.render(self)
#     299 if self.checked_render is False:
#     300     self.checked_render = True
# --> 301     return env_render_passive_checker(self.env)
#     302 else:
#     303     return self.env.render()
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/utils/passive_env_checker.py:361, in env_render_passive_checker(env)
#     355     else:
#     356         assert env.render_mode is None or env.render_mode in render_modes, (
#     357             "The environment was initialized successfully however with an unsupported render mode. "
#     358             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     359         )
# --> 361 result = env.render()
#     362 if env.render_mode is not None:
#     363     _check_render_return(env.render_mode, result)
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/envs/mujoco/mujoco_env.py:159, in MujocoEnv.render(self)
#     155 def render(self):
#     156     """
#     157     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     158     """
# --> 159     return self.mujoco_renderer.render(self.render_mode)
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:731, in MujocoRenderer.render(self, render_mode)
#     726 if render_mode != "human":
#     727     assert (
#     728         self.width is not None and self.height is not None
#     729     ), f"The width: {self.width} and height: {self.height} cannot be `None` when the render_mode is not `human`."
# --> 731 viewer = self._get_viewer(render_mode=render_mode)
#     733 if render_mode in ["rgb_array", "depth_array", "rgbd_tuple"]:
#     734     return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#
# File ~/miniconda3/envs/exoskeleton/lib/python3.13/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:764, in MujocoRenderer._get_viewer(self, render_mode)
#     755     self.viewer = OffScreenViewer(
#     756         self.model,
#     757         self.data,
#    (...)    761         self._vopt,
#     762     )
#     763 else:
# --> 764     raise AttributeError(
#     765         f"Unexpected mode: {render_mode}, expected modes: human, rgb_array, depth_array, or rgbd_tuple"
#     766     )
#     767 # Add default camera parameters
#     768 self._set_cam_config()
#
# AttributeError: Unexpected mode: None, expected modes: human, rgb_array, depth_array, or rgbd_tuple
